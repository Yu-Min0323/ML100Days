# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    """
    計算 MSE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MSE
    """
    mse = sum((y - yp) ** 2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 179.035
# The Mean absolute error is 10.696

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# https://www.kaggle.com/c/plant-pathology-2021-fgvc8/overview/description
# 1. 你選的這組資料為何重要
#     現階段在判斷蘋果樹是否有患病皆是由人工方式去篩選，倘若可以使用影像的判讀的方式便能減輕人力資源的消耗
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#     資料由2020-FGVC7 challenge competition所提供
# 3. 蒐集而來的資料型態為何
#     23,000張蘋果葉病(foliar diseases)的RGB影像
# 4. 這組資料想解決的問題如何評估
#     利用單張葉子的照片判斷此蘋果樹所患的疾病
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#     我認為要提升整體的業績取決於所有計程車的載客率，舉例來說，假設將整個台北市劃分為比較小的區塊，倘若能夠去計算每個區塊在特定時間區間內的載客率，並提供給司機，司機便能夠離開載客率低的區域並前往載客率高的區域，進而提高整個台北市的載客率。
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#     時間上為星期幾、當天的時段、天氣、特殊節慶等皆會影響特定區域的載客率，可以透過GPS定位系統得知在特定區域內的計程車數量，並在乘客乘車時累加乘車次數，每五分鐘統計一次，並記錄上述的數據，將載客次數除以車輛便能得到載客率。
# 3. 蒐集而來的資料型態為何
#     蒐集而來的資料可以以excel表格紀錄。
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#     倘若能夠讓空閒的司機知道此時此刻前往哪個地點能夠遇到乘客，便能夠提高整體載客率並提升業績，亦能將改善過後的數據再記錄下來進行模型的調整。可以計算每周或是每月的整體載客率來評估此方法是否有效。
